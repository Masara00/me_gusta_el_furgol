# %% [markdown]
# ##  Agregamos las librerias necesarias

# %%
import sqlite3
import pymysql
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# #### Credenciales

# %%
username = "admin"
password = "12345678"
host = "database-1.ckwuwtn1emlt.us-east-1.rds.amazonaws.com" 
port = "3306"

# %%
print(username)
print(password)
print(host)
# Out:
# admin
# 12345678
# database-1.ckwuwtn1emlt.us-east-1.rds.amazonaws.com

# %% [markdown]
# Vamos a cargar el fichero .csv desde el que ingestar los datos

# %%
db_aws=pd.read_csv('E:\Bootcamp_22\Javier\Repositorios\me_gusta_el_furgol\data\df_partidos.csv',sep=',',index_col=0)
db_aws.head()
# Out:
#       season        date country_name                  home_team  \
# 0  2008/2009  2008-08-30        Spain                Valencia CF
# 1  2008/2009  2008-08-31        Spain                 CA Osasuna
# 2  2008/2009  2008-08-31        Spain  RC Deportivo de La Coruña
# 3  2008/2009  2008-08-31        Spain                CD Numancia
# 4  2008/2009  2008-08-31        Spain           Racing Santander
#
#         away_team  home_team_goal  away_team_goal  result
# 0    RCD Mallorca               3               0       1
# 1   Villarreal CF               1               1       0
# 2  Real Madrid CF               2               1       1
# 3    FC Barcelona               1               0       1
# 4      Sevilla FC               1               1       0

# %%
db = pymysql.connect(host = host,
                     user = username,
                     password = password,
                     cursorclass = pymysql.cursors.DictCursor)

# %%
cursor = db.cursor()
create_db = '''CREATE DATABASE DB_FURBOL'''
cursor.execute(create_db)
# Out:
# 1

# %%
cursor.execute('SHOW DATABASES')
cursor.fetchall()
# Out:
# [{'Database': 'DB_FURBOL'},
#  {'Database': 'information_schema'},
#  {'Database': 'mysql'},
#  {'Database': 'performance_schema'},
#  {'Database': 'sys'}]

# %% [markdown]
# Generamos la tabla dentro de la Base de Datos para AWS

# %%
cursor.connection.commit()
use_db = ''' USE DB_FURBOL'''
cursor.execute(use_db)
# Out:
# 0

# %%
query = '''
CREATE TABLE DB_FURBOL (
    season TEXT,
    date TEXT,
    country_name TEXT,
    home_team TEXT,
    away_team TEXT,
    home_team_goal INT,
    away_team_goal INT,
    result  INT
);'''
cursor.execute(query)
# Out:
# 0

# %%
engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}".format(user = username, pw = password, host = host, db = 'DB_FURBOL'))

# %%
db_aws.to_sql(name='DB_FURBOL', con=engine, if_exists= 'append', index=False)

# %%
db_prueba = pymysql.connect(host = host,
                     user = username,
                     password = password,
                     cursorclass = pymysql.cursors.DictCursor
)

cursor = db.cursor()

cursor.connection.commit()
use_db = ''' USE DB_FURBOL'''
cursor.execute(use_db)


sql = '''SELECT * FROM DB_FURBOL'''
cursor.execute(sql)
mi_tabla = cursor.fetchall()
mi_tabla
# Out:
# [{'season': '2008/2009',
#   'date': '2008-08-30',
#   'country_name': 'Spain',
#   'home_team': 'Valencia CF',
#   'away_team': 'RCD Mallorca',
#   'home_team_goal': 3,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-08-31',
#   'country_name': 'Spain',
#   'home_team': 'CA Osasuna',
#   'away_team': 'Villarreal CF',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-08-31',
#   'country_name': 'Spain',
#   'home_team': 'RC Deportivo de La Coruña',
#   'away_team': 'Real Madrid CF',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-08-31',
#   'country_name': 'Spain',
#   'home_team': 'CD Numancia',
#   'away_team': 'FC Barcelona',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-08-31',
#   'country_name': 'Spain',
#   'home_team': 'Racing Santander',
#   'away_team': 'Sevilla FC',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-08-31',
#   'country_name': 'Spain',
#   'home_team': 'Real Sporting de Gijón',
#   'away_team': 'Getafe CF',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-08-31',
#   'country_name': 'Spain',
#   'home_team': 'Real Betis Balompié',
#   'away_team': 'RC Recreativo',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-08-30',
#   'country_name': 'Spain',
#   'home_team': 'RCD Espanyol',
#   'away_team': 'Real Valladolid',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-08-31',
#   'country_name': 'Spain',
#   'home_team': 'Athletic Club de Bilbao',
#   'away_team': 'UD Almería',
#   'home_team_goal': 1,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-08-31',
#   'country_name': 'Spain',
#   'home_team': 'Atlético Madrid',
#   'away_team': 'Málaga CF',
#   'home_team_goal': 4,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-09',
#   'country_name': 'Spain',
#   'home_team': 'Sevilla FC',
#   'away_team': 'RC Recreativo',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-09',
#   'country_name': 'Spain',
#   'home_team': 'Racing Santander',
#   'away_team': 'Real Sporting de Gijón',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-09',
#   'country_name': 'Spain',
#   'home_team': 'CD Numancia',
#   'away_team': 'Real Betis Balompié',
#   'home_team_goal': 2,
#   'away_team_goal': 4,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-11-09',
#   'country_name': 'Spain',
#   'home_team': 'RC Deportivo de La Coruña',
#   'away_team': 'RCD Espanyol',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-09',
#   'country_name': 'Spain',
#   'home_team': 'CA Osasuna',
#   'away_team': 'Atlético Madrid',
#   'home_team_goal': 0,
#   'away_team_goal': 0,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-11-09',
#   'country_name': 'Spain',
#   'home_team': 'Villarreal CF',
#   'away_team': 'UD Almería',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-08',
#   'country_name': 'Spain',
#   'home_team': 'Real Madrid CF',
#   'away_team': 'Málaga CF',
#   'home_team_goal': 4,
#   'away_team_goal': 3,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-08',
#   'country_name': 'Spain',
#   'home_team': 'FC Barcelona',
#   'away_team': 'Real Valladolid',
#   'home_team_goal': 6,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-09',
#   'country_name': 'Spain',
#   'home_team': 'Getafe CF',
#   'away_team': 'Valencia CF',
#   'home_team_goal': 0,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-11-09',
#   'country_name': 'Spain',
#   'home_team': 'RCD Mallorca',
#   'away_team': 'Athletic Club de Bilbao',
#   'home_team_goal': 3,
#   'away_team_goal': 3,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-11-16',
#   'country_name': 'Spain',
#   'home_team': 'Real Betis Balompié',
#   'away_team': 'Racing Santander',
#   'home_team_goal': 3,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-15',
#   'country_name': 'Spain',
#   'home_team': 'Valencia CF',
#   'away_team': 'Real Sporting de Gijón',
#   'home_team_goal': 2,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-11-16',
#   'country_name': 'Spain',
#   'home_team': 'RCD Espanyol',
#   'away_team': 'CD Numancia',
#   'home_team_goal': 3,
#   'away_team_goal': 4,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-11-16',
#   'country_name': 'Spain',
#   'home_team': 'Atlético Madrid',
#   'away_team': 'RC Deportivo de La Coruña',
#   'home_team_goal': 4,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-16',
#   'country_name': 'Spain',
#   'home_team': 'Athletic Club de Bilbao',
#   'away_team': 'CA Osasuna',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-16',
#   'country_name': 'Spain',
#   'home_team': 'UD Almería',
#   'away_team': 'RCD Mallorca',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-16',
#   'country_name': 'Spain',
#   'home_team': 'Málaga CF',
#   'away_team': 'Villarreal CF',
#   'home_team_goal': 2,
#   'away_team_goal': 2,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-11-15',
#   'country_name': 'Spain',
#   'home_team': 'Real Valladolid',
#   'away_team': 'Real Madrid CF',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-16',
#   'country_name': 'Spain',
#   'home_team': 'Getafe CF',
#   'away_team': 'Sevilla FC',
#   'home_team_goal': 0,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-11-16',
#   'country_name': 'Spain',
#   'home_team': 'RC Recreativo',
#   'away_team': 'FC Barcelona',
#   'home_team_goal': 0,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-11-23',
#   'country_name': 'Spain',
#   'home_team': 'Racing Santander',
#   'away_team': 'RCD Espanyol',
#   'home_team_goal': 3,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-22',
#   'country_name': 'Spain',
#   'home_team': 'Villarreal CF',
#   'away_team': 'Real Valladolid',
#   'home_team_goal': 0,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-11-23',
#   'country_name': 'Spain',
#   'home_team': 'FC Barcelona',
#   'away_team': 'Getafe CF',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-11-22',
#   'country_name': 'Spain',
#   'home_team': 'Sevilla FC',
#   'away_team': 'Valencia CF',
#   'home_team_goal': 0,
#   'away_team_goal': 0,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-11-23',
#   'country_name': 'Spain',
#   'home_team': 'CA Osasuna',
#   'away_team': 'UD Almería',
#   'home_team_goal': 3,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-23',
#   'country_name': 'Spain',
#   'home_team': 'RC Deportivo de La Coruña',
#   'away_team': 'Athletic Club de Bilbao',
#   'home_team_goal': 3,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-23',
#   'country_name': 'Spain',
#   'home_team': 'RCD Mallorca',
#   'away_team': 'Málaga CF',
#   'home_team_goal': 2,
#   'away_team_goal': 2,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-11-22',
#   'country_name': 'Spain',
#   'home_team': 'Real Madrid CF',
#   'away_team': 'RC Recreativo',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-23',
#   'country_name': 'Spain',
#   'home_team': 'CD Numancia',
#   'away_team': 'Atlético Madrid',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-11-23',
#   'country_name': 'Spain',
#   'home_team': 'Real Sporting de Gijón',
#   'away_team': 'Real Betis Balompié',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-11-30',
#   'country_name': 'Spain',
#   'home_team': 'UD Almería',
#   'away_team': 'RC Deportivo de La Coruña',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-11-30',
#   'country_name': 'Spain',
#   'home_team': 'RC Recreativo',
#   'away_team': 'Villarreal CF',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-11-30',
#   'country_name': 'Spain',
#   'home_team': 'RCD Espanyol',
#   'away_team': 'Real Sporting de Gijón',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-11-30',
#   'country_name': 'Spain',
#   'home_team': 'Atlético Madrid',
#   'away_team': 'Racing Santander',
#   'home_team_goal': 4,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-30',
#   'country_name': 'Spain',
#   'home_team': 'Valencia CF',
#   'away_team': 'Real Betis Balompié',
#   'home_team_goal': 3,
#   'away_team_goal': 2,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-30',
#   'country_name': 'Spain',
#   'home_team': 'Real Valladolid',
#   'away_team': 'RCD Mallorca',
#   'home_team_goal': 3,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-29',
#   'country_name': 'Spain',
#   'home_team': 'Sevilla FC',
#   'away_team': 'FC Barcelona',
#   'home_team_goal': 0,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-11-30',
#   'country_name': 'Spain',
#   'home_team': 'Málaga CF',
#   'away_team': 'CA Osasuna',
#   'home_team_goal': 4,
#   'away_team_goal': 2,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-29',
#   'country_name': 'Spain',
#   'home_team': 'Getafe CF',
#   'away_team': 'Real Madrid CF',
#   'home_team_goal': 3,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-11-30',
#   'country_name': 'Spain',
#   'home_team': 'Athletic Club de Bilbao',
#   'away_team': 'CD Numancia',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-12-07',
#   'country_name': 'Spain',
#   'home_team': 'RC Deportivo de La Coruña',
#   'away_team': 'Málaga CF',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-12-07',
#   'country_name': 'Spain',
#   'home_team': 'CA Osasuna',
#   'away_team': 'Real Valladolid',
#   'home_team_goal': 3,
#   'away_team_goal': 3,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-12-07',
#   'country_name': 'Spain',
#   'home_team': 'RCD Mallorca',
#   'away_team': 'RC Recreativo',
#   'home_team_goal': 2,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-12-06',
#   'country_name': 'Spain',
#   'home_team': 'Villarreal CF',
#   'away_team': 'Getafe CF',
#   'home_team_goal': 3,
#   'away_team_goal': 3,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-12-06',
#   'country_name': 'Spain',
#   'home_team': 'FC Barcelona',
#   'away_team': 'Valencia CF',
#   'home_team_goal': 4,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-12-07',
#   'country_name': 'Spain',
#   'home_team': 'CD Numancia',
#   'away_team': 'UD Almería',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-12-07',
#   'country_name': 'Spain',
#   'home_team': 'Racing Santander',
#   'away_team': 'Athletic Club de Bilbao',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-12-07',
#   'country_name': 'Spain',
#   'home_team': 'Real Betis Balompié',
#   'away_team': 'RCD Espanyol',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-12-07',
#   'country_name': 'Spain',
#   'home_team': 'Real Madrid CF',
#   'away_team': 'Sevilla FC',
#   'home_team_goal': 3,
#   'away_team_goal': 4,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-12-06',
#   'country_name': 'Spain',
#   'home_team': 'Real Sporting de Gijón',
#   'away_team': 'Atlético Madrid',
#   'home_team_goal': 2,
#   'away_team_goal': 5,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-12-13',
#   'country_name': 'Spain',
#   'home_team': 'FC Barcelona',
#   'away_team': 'Real Madrid CF',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-12-14',
#   'country_name': 'Spain',
#   'home_team': 'Athletic Club de Bilbao',
#   'away_team': 'Real Sporting de Gijón',
#   'home_team_goal': 3,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-12-14',
#   'country_name': 'Spain',
#   'home_team': 'Atlético Madrid',
#   'away_team': 'Real Betis Balompié',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-12-14',
#   'country_name': 'Spain',
#   'home_team': 'UD Almería',
#   'away_team': 'Racing Santander',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-12-14',
#   'country_name': 'Spain',
#   'home_team': 'Real Valladolid',
#   'away_team': 'RC Deportivo de La Coruña',
#   'home_team_goal': 3,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-12-14',
#   'country_name': 'Spain',
#   'home_team': 'RC Recreativo',
#   'away_team': 'CA Osasuna',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-12-14',
#   'country_name': 'Spain',
#   'home_team': 'Getafe CF',
#   'away_team': 'RCD Mallorca',
#   'home_team_goal': 4,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-12-14',
#   'country_name': 'Spain',
#   'home_team': 'Sevilla FC',
#   'away_team': 'Villarreal CF',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-12-13',
#   'country_name': 'Spain',
#   'home_team': 'Valencia CF',
#   'away_team': 'RCD Espanyol',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-12-14',
#   'country_name': 'Spain',
#   'home_team': 'Málaga CF',
#   'away_team': 'CD Numancia',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-12-21',
#   'country_name': 'Spain',
#   'home_team': 'Real Betis Balompié',
#   'away_team': 'Athletic Club de Bilbao',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-12-21',
#   'country_name': 'Spain',
#   'home_team': 'Real Sporting de Gijón',
#   'away_team': 'UD Almería',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-12-21',
#   'country_name': 'Spain',
#   'home_team': 'Racing Santander',
#   'away_team': 'Málaga CF',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-12-21',
#   'country_name': 'Spain',
#   'home_team': 'RC Deportivo de La Coruña',
#   'away_team': 'RC Recreativo',
#   'home_team_goal': 4,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-12-21',
#   'country_name': 'Spain',
#   'home_team': 'RCD Mallorca',
#   'away_team': 'Sevilla FC',
#   'home_team_goal': 0,
#   'away_team_goal': 0,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-12-21',
#   'country_name': 'Spain',
#   'home_team': 'Villarreal CF',
#   'away_team': 'FC Barcelona',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-12-20',
#   'country_name': 'Spain',
#   'home_team': 'Real Madrid CF',
#   'away_team': 'Valencia CF',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-12-20',
#   'country_name': 'Spain',
#   'home_team': 'RCD Espanyol',
#   'away_team': 'Atlético Madrid',
#   'home_team_goal': 2,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-12-21',
#   'country_name': 'Spain',
#   'home_team': 'CD Numancia',
#   'away_team': 'Real Valladolid',
#   'home_team_goal': 4,
#   'away_team_goal': 3,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-12-21',
#   'country_name': 'Spain',
#   'home_team': 'CA Osasuna',
#   'away_team': 'Getafe CF',
#   'home_team_goal': 5,
#   'away_team_goal': 2,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-04',
#   'country_name': 'Spain',
#   'home_team': 'Getafe CF',
#   'away_team': 'RC Deportivo de La Coruña',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-01-04',
#   'country_name': 'Spain',
#   'home_team': 'Málaga CF',
#   'away_team': 'Real Sporting de Gijón',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-04',
#   'country_name': 'Spain',
#   'home_team': 'Real Valladolid',
#   'away_team': 'Racing Santander',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-01-04',
#   'country_name': 'Spain',
#   'home_team': 'RC Recreativo',
#   'away_team': 'CD Numancia',
#   'home_team_goal': 3,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-04',
#   'country_name': 'Spain',
#   'home_team': 'Sevilla FC',
#   'away_team': 'CA Osasuna',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-01-03',
#   'country_name': 'Spain',
#   'home_team': 'FC Barcelona',
#   'away_team': 'RCD Mallorca',
#   'home_team_goal': 3,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-04',
#   'country_name': 'Spain',
#   'home_team': 'Real Madrid CF',
#   'away_team': 'Villarreal CF',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-03',
#   'country_name': 'Spain',
#   'home_team': 'Valencia CF',
#   'away_team': 'Atlético Madrid',
#   'home_team_goal': 3,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-04',
#   'country_name': 'Spain',
#   'home_team': 'Athletic Club de Bilbao',
#   'away_team': 'RCD Espanyol',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-01-04',
#   'country_name': 'Spain',
#   'home_team': 'UD Almería',
#   'away_team': 'Real Betis Balompié',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-11',
#   'country_name': 'Spain',
#   'home_team': 'Real Sporting de Gijón',
#   'away_team': 'Real Valladolid',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-11',
#   'country_name': 'Spain',
#   'home_team': 'Real Betis Balompié',
#   'away_team': 'Málaga CF',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-01-11',
#   'country_name': 'Spain',
#   'home_team': 'Atlético Madrid',
#   'away_team': 'Athletic Club de Bilbao',
#   'home_team_goal': 2,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-01-11',
#   'country_name': 'Spain',
#   'home_team': 'RCD Espanyol',
#   'away_team': 'UD Almería',
#   'home_team_goal': 2,
#   'away_team_goal': 2,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-01-11',
#   'country_name': 'Spain',
#   'home_team': 'Racing Santander',
#   'away_team': 'RC Recreativo',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-01-11',
#   'country_name': 'Spain',
#   'home_team': 'CD Numancia',
#   'away_team': 'Getafe CF',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-11',
#   'country_name': 'Spain',
#   'home_team': 'CA Osasuna',
#   'away_team': 'FC Barcelona',
#   'home_team_goal': 2,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-01-11',
#   'country_name': 'Spain',
#   'home_team': 'RCD Mallorca',
#   'away_team': 'Real Madrid CF',
#   'home_team_goal': 0,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-01-10',
#   'country_name': 'Spain',
#   'home_team': 'Valencia CF',
#   'away_team': 'Villarreal CF',
#   'home_team_goal': 3,
#   'away_team_goal': 3,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-01-10',
#   'country_name': 'Spain',
#   'home_team': 'RC Deportivo de La Coruña',
#   'away_team': 'Sevilla FC',
#   'home_team_goal': 1,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-01-18',
#   'country_name': 'Spain',
#   'home_team': 'Athletic Club de Bilbao',
#   'away_team': 'Valencia CF',
#   'home_team_goal': 3,
#   'away_team_goal': 2,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-18',
#   'country_name': 'Spain',
#   'home_team': 'UD Almería',
#   'away_team': 'Atlético Madrid',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-01-18',
#   'country_name': 'Spain',
#   'home_team': 'Málaga CF',
#   'away_team': 'RCD Espanyol',
#   'home_team_goal': 4,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-18',
#   'country_name': 'Spain',
#   'home_team': 'Real Valladolid',
#   'away_team': 'Real Betis Balompié',
#   'home_team_goal': 1,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-01-18',
#   'country_name': 'Spain',
#   'home_team': 'RC Recreativo',
#   'away_team': 'Real Sporting de Gijón',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-18',
#   'country_name': 'Spain',
#   'home_team': 'Getafe CF',
#   'away_team': 'Racing Santander',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-01-17',
#   'country_name': 'Spain',
#   'home_team': 'Sevilla FC',
#   'away_team': 'CD Numancia',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-17',
#   'country_name': 'Spain',
#   'home_team': 'FC Barcelona',
#   'away_team': 'RC Deportivo de La Coruña',
#   'home_team_goal': 5,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-18',
#   'country_name': 'Spain',
#   'home_team': 'Real Madrid CF',
#   'away_team': 'CA Osasuna',
#   'home_team_goal': 3,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-18',
#   'country_name': 'Spain',
#   'home_team': 'Villarreal CF',
#   'away_team': 'RCD Mallorca',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-09-14',
#   'country_name': 'Spain',
#   'home_team': 'Villarreal CF',
#   'away_team': 'RC Deportivo de La Coruña',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-09-14',
#   'country_name': 'Spain',
#   'home_team': 'Real Madrid CF',
#   'away_team': 'CD Numancia',
#   'home_team_goal': 4,
#   'away_team_goal': 3,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-09-13',
#   'country_name': 'Spain',
#   'home_team': 'FC Barcelona',
#   'away_team': 'Racing Santander',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-09-13',
#   'country_name': 'Spain',
#   'home_team': 'Sevilla FC',
#   'away_team': 'Real Sporting de Gijón',
#   'home_team_goal': 4,
#   'away_team_goal': 3,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-09-14',
#   'country_name': 'Spain',
#   'home_team': 'Getafe CF',
#   'away_team': 'Real Betis Balompié',
#   'home_team_goal': 0,
#   'away_team_goal': 0,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-09-14',
#   'country_name': 'Spain',
#   'home_team': 'RC Recreativo',
#   'away_team': 'RCD Espanyol',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-09-13',
#   'country_name': 'Spain',
#   'home_team': 'Real Valladolid',
#   'away_team': 'Atlético Madrid',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-09-14',
#   'country_name': 'Spain',
#   'home_team': 'Málaga CF',
#   'away_team': 'Athletic Club de Bilbao',
#   'home_team_goal': 0,
#   'away_team_goal': 0,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-09-14',
#   'country_name': 'Spain',
#   'home_team': 'UD Almería',
#   'away_team': 'Valencia CF',
#   'home_team_goal': 2,
#   'away_team_goal': 2,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-09-14',
#   'country_name': 'Spain',
#   'home_team': 'RCD Mallorca',
#   'away_team': 'CA Osasuna',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-01-24',
#   'country_name': 'Spain',
#   'home_team': 'FC Barcelona',
#   'away_team': 'CD Numancia',
#   'home_team_goal': 4,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-25',
#   'country_name': 'Spain',
#   'home_team': 'Real Madrid CF',
#   'away_team': 'RC Deportivo de La Coruña',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-24',
#   'country_name': 'Spain',
#   'home_team': 'Villarreal CF',
#   'away_team': 'CA Osasuna',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-01-25',
#   'country_name': 'Spain',
#   'home_team': 'RCD Mallorca',
#   'away_team': 'Valencia CF',
#   'home_team_goal': 3,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-25',
#   'country_name': 'Spain',
#   'home_team': 'Sevilla FC',
#   'away_team': 'Racing Santander',
#   'home_team_goal': 0,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-01-25',
#   'country_name': 'Spain',
#   'home_team': 'Getafe CF',
#   'away_team': 'Real Sporting de Gijón',
#   'home_team_goal': 5,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-25',
#   'country_name': 'Spain',
#   'home_team': 'RC Recreativo',
#   'away_team': 'Real Betis Balompié',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-01-25',
#   'country_name': 'Spain',
#   'home_team': 'Real Valladolid',
#   'away_team': 'RCD Espanyol',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-01-25',
#   'country_name': 'Spain',
#   'home_team': 'Málaga CF',
#   'away_team': 'Atlético Madrid',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-01-25',
#   'country_name': 'Spain',
#   'home_team': 'UD Almería',
#   'away_team': 'Athletic Club de Bilbao',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-01',
#   'country_name': 'Spain',
#   'home_team': 'Racing Santander',
#   'away_team': 'FC Barcelona',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-01-31',
#   'country_name': 'Spain',
#   'home_team': 'CD Numancia',
#   'away_team': 'Real Madrid CF',
#   'home_team_goal': 0,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-02-01',
#   'country_name': 'Spain',
#   'home_team': 'RC Deportivo de La Coruña',
#   'away_team': 'Villarreal CF',
#   'home_team_goal': 3,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-01',
#   'country_name': 'Spain',
#   'home_team': 'CA Osasuna',
#   'away_team': 'RCD Mallorca',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-01',
#   'country_name': 'Spain',
#   'home_team': 'Real Sporting de Gijón',
#   'away_team': 'Sevilla FC',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-01',
#   'country_name': 'Spain',
#   'home_team': 'Real Betis Balompié',
#   'away_team': 'Getafe CF',
#   'home_team_goal': 2,
#   'away_team_goal': 2,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-02-01',
#   'country_name': 'Spain',
#   'home_team': 'RCD Espanyol',
#   'away_team': 'RC Recreativo',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-02-01',
#   'country_name': 'Spain',
#   'home_team': 'Atlético Madrid',
#   'away_team': 'Real Valladolid',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-01-31',
#   'country_name': 'Spain',
#   'home_team': 'Athletic Club de Bilbao',
#   'away_team': 'Málaga CF',
#   'home_team_goal': 3,
#   'away_team_goal': 2,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-01',
#   'country_name': 'Spain',
#   'home_team': 'Valencia CF',
#   'away_team': 'UD Almería',
#   'home_team_goal': 3,
#   'away_team_goal': 2,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-08',
#   'country_name': 'Spain',
#   'home_team': 'RCD Mallorca',
#   'away_team': 'RC Deportivo de La Coruña',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-02-08',
#   'country_name': 'Spain',
#   'home_team': 'Villarreal CF',
#   'away_team': 'CD Numancia',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-07',
#   'country_name': 'Spain',
#   'home_team': 'Real Madrid CF',
#   'away_team': 'Racing Santander',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-08',
#   'country_name': 'Spain',
#   'home_team': 'FC Barcelona',
#   'away_team': 'Real Sporting de Gijón',
#   'home_team_goal': 3,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-07',
#   'country_name': 'Spain',
#   'home_team': 'Sevilla FC',
#   'away_team': 'Real Betis Balompié',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-02-08',
#   'country_name': 'Spain',
#   'home_team': 'Getafe CF',
#   'away_team': 'RCD Espanyol',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-02-08',
#   'country_name': 'Spain',
#   'home_team': 'RC Recreativo',
#   'away_team': 'Atlético Madrid',
#   'home_team_goal': 0,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-02-08',
#   'country_name': 'Spain',
#   'home_team': 'Real Valladolid',
#   'away_team': 'Athletic Club de Bilbao',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-08',
#   'country_name': 'Spain',
#   'home_team': 'Málaga CF',
#   'away_team': 'UD Almería',
#   'home_team_goal': 3,
#   'away_team_goal': 2,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-08',
#   'country_name': 'Spain',
#   'home_team': 'CA Osasuna',
#   'away_team': 'Valencia CF',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-14',
#   'country_name': 'Spain',
#   'home_team': 'Real Betis Balompié',
#   'away_team': 'FC Barcelona',
#   'home_team_goal': 2,
#   'away_team_goal': 2,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-02-15',
#   'country_name': 'Spain',
#   'home_team': 'Athletic Club de Bilbao',
#   'away_team': 'RC Recreativo',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-02-15',
#   'country_name': 'Spain',
#   'home_team': 'Real Sporting de Gijón',
#   'away_team': 'Real Madrid CF',
#   'home_team_goal': 0,
#   'away_team_goal': 4,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-02-14',
#   'country_name': 'Spain',
#   'home_team': 'Valencia CF',
#   'away_team': 'Málaga CF',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-02-15',
#   'country_name': 'Spain',
#   'home_team': 'UD Almería',
#   'away_team': 'Real Valladolid',
#   'home_team_goal': 3,
#   'away_team_goal': 2,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-15',
#   'country_name': 'Spain',
#   'home_team': 'Atlético Madrid',
#   'away_team': 'Getafe CF',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-02-15',
#   'country_name': 'Spain',
#   'home_team': 'RCD Espanyol',
#   'away_team': 'Sevilla FC',
#   'home_team_goal': 0,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-02-15',
#   'country_name': 'Spain',
#   'home_team': 'Racing Santander',
#   'away_team': 'Villarreal CF',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-02-15',
#   'country_name': 'Spain',
#   'home_team': 'CD Numancia',
#   'away_team': 'RCD Mallorca',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-02-14',
#   'country_name': 'Spain',
#   'home_team': 'RC Deportivo de La Coruña',
#   'away_team': 'CA Osasuna',
#   'home_team_goal': 0,
#   'away_team_goal': 0,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-02-21',
#   'country_name': 'Spain',
#   'home_team': 'FC Barcelona',
#   'away_team': 'RCD Espanyol',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-02-22',
#   'country_name': 'Spain',
#   'home_team': 'Getafe CF',
#   'away_team': 'Athletic Club de Bilbao',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-02-22',
#   'country_name': 'Spain',
#   'home_team': 'RC Deportivo de La Coruña',
#   'away_team': 'Valencia CF',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-02-22',
#   'country_name': 'Spain',
#   'home_team': 'CA Osasuna',
#   'away_team': 'CD Numancia',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-22',
#   'country_name': 'Spain',
#   'home_team': 'RCD Mallorca',
#   'away_team': 'Racing Santander',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-21',
#   'country_name': 'Spain',
#   'home_team': 'Villarreal CF',
#   'away_team': 'Real Sporting de Gijón',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-21',
#   'country_name': 'Spain',
#   'home_team': 'Real Madrid CF',
#   'away_team': 'Real Betis Balompié',
#   'home_team_goal': 6,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-22',
#   'country_name': 'Spain',
#   'home_team': 'RC Recreativo',
#   'away_team': 'UD Almería',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-02-22',
#   'country_name': 'Spain',
#   'home_team': 'Real Valladolid',
#   'away_team': 'Málaga CF',
#   'home_team_goal': 1,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-02-21',
#   'country_name': 'Spain',
#   'home_team': 'Sevilla FC',
#   'away_team': 'Atlético Madrid',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-03-01',
#   'country_name': 'Spain',
#   'home_team': 'Málaga CF',
#   'away_team': 'RC Recreativo',
#   'home_team_goal': 0,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-03-01',
#   'country_name': 'Spain',
#   'home_team': 'UD Almería',
#   'away_team': 'Getafe CF',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-28',
#   'country_name': 'Spain',
#   'home_team': 'Athletic Club de Bilbao',
#   'away_team': 'Sevilla FC',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-03-01',
#   'country_name': 'Spain',
#   'home_team': 'Atlético Madrid',
#   'away_team': 'FC Barcelona',
#   'home_team_goal': 4,
#   'away_team_goal': 3,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-02-28',
#   'country_name': 'Spain',
#   'home_team': 'RCD Espanyol',
#   'away_team': 'Real Madrid CF',
#   'home_team_goal': 0,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-03-01',
#   'country_name': 'Spain',
#   'home_team': 'Real Betis Balompié',
#   'away_team': 'Villarreal CF',
#   'home_team_goal': 2,
#   'away_team_goal': 2,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-03-01',
#   'country_name': 'Spain',
#   'home_team': 'Real Sporting de Gijón',
#   'away_team': 'RCD Mallorca',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-03-01',
#   'country_name': 'Spain',
#   'home_team': 'Racing Santander',
#   'away_team': 'CA Osasuna',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-03-01',
#   'country_name': 'Spain',
#   'home_team': 'CD Numancia',
#   'away_team': 'RC Deportivo de La Coruña',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-03-01',
#   'country_name': 'Spain',
#   'home_team': 'Valencia CF',
#   'away_team': 'Real Valladolid',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-03-08',
#   'country_name': 'Spain',
#   'home_team': 'CD Numancia',
#   'away_team': 'Valencia CF',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-03-08',
#   'country_name': 'Spain',
#   'home_team': 'CA Osasuna',
#   'away_team': 'Real Sporting de Gijón',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-03-08',
#   'country_name': 'Spain',
#   'home_team': 'RCD Mallorca',
#   'away_team': 'Real Betis Balompié',
#   'home_team_goal': 3,
#   'away_team_goal': 3,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-03-07',
#   'country_name': 'Spain',
#   'home_team': 'Villarreal CF',
#   'away_team': 'RCD Espanyol',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-03-07',
#   'country_name': 'Spain',
#   'home_team': 'Real Madrid CF',
#   'away_team': 'Atlético Madrid',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-03-07',
#   'country_name': 'Spain',
#   'home_team': 'FC Barcelona',
#   'away_team': 'Athletic Club de Bilbao',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-03-08',
#   'country_name': 'Spain',
#   'home_team': 'Sevilla FC',
#   'away_team': 'UD Almería',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-03-08',
#   'country_name': 'Spain',
#   'home_team': 'Getafe CF',
#   'away_team': 'Málaga CF',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-03-08',
#   'country_name': 'Spain',
#   'home_team': 'RC Recreativo',
#   'away_team': 'Real Valladolid',
#   'home_team_goal': 2,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-03-08',
#   'country_name': 'Spain',
#   'home_team': 'RC Deportivo de La Coruña',
#   'away_team': 'Racing Santander',
#   'home_team_goal': 5,
#   'away_team_goal': 3,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-03-15',
#   'country_name': 'Spain',
#   'home_team': 'Real Sporting de Gijón',
#   'away_team': 'RC Deportivo de La Coruña',
#   'home_team_goal': 3,
#   'away_team_goal': 2,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-03-15',
#   'country_name': 'Spain',
#   'home_team': 'Real Betis Balompié',
#   'away_team': 'CA Osasuna',
#   'home_team_goal': 0,
#   'away_team_goal': 0,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-03-15',
#   'country_name': 'Spain',
#   'home_team': 'RCD Espanyol',
#   'away_team': 'RCD Mallorca',
#   'home_team_goal': 3,
#   'away_team_goal': 3,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-03-15',
#   'country_name': 'Spain',
#   'home_team': 'Atlético Madrid',
#   'away_team': 'Villarreal CF',
#   'home_team_goal': 3,
#   'away_team_goal': 2,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-03-15',
#   'country_name': 'Spain',
#   'home_team': 'UD Almería',
#   'away_team': 'FC Barcelona',
#   'home_team_goal': 0,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-03-15',
#   'country_name': 'Spain',
#   'home_team': 'Málaga CF',
#   'away_team': 'Sevilla FC',
#   'home_team_goal': 2,
#   'away_team_goal': 2,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-03-15',
#   'country_name': 'Spain',
#   'home_team': 'Real Valladolid',
#   'away_team': 'Getafe CF',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-03-14',
#   'country_name': 'Spain',
#   'home_team': 'Valencia CF',
#   'away_team': 'RC Recreativo',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-03-14',
#   'country_name': 'Spain',
#   'home_team': 'Athletic Club de Bilbao',
#   'away_team': 'Real Madrid CF',
#   'home_team_goal': 2,
#   'away_team_goal': 5,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-03-15',
#   'country_name': 'Spain',
#   'home_team': 'Racing Santander',
#   'away_team': 'CD Numancia',
#   'home_team_goal': 5,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-03-22',
#   'country_name': 'Spain',
#   'home_team': 'Racing Santander',
#   'away_team': 'Valencia CF',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-03-21',
#   'country_name': 'Spain',
#   'home_team': 'Sevilla FC',
#   'away_team': 'Real Valladolid',
#   'home_team_goal': 4,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-03-22',
#   'country_name': 'Spain',
#   'home_team': 'Getafe CF',
#   'away_team': 'RC Recreativo',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-03-22',
#   'country_name': 'Spain',
#   'home_team': 'CD Numancia',
#   'away_team': 'Real Sporting de Gijón',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-03-22',
#   'country_name': 'Spain',
#   'home_team': 'RC Deportivo de La Coruña',
#   'away_team': 'Real Betis Balompié',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-03-22',
#   'country_name': 'Spain',
#   'home_team': 'CA Osasuna',
#   'away_team': 'RCD Espanyol',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-03-22',
#   'country_name': 'Spain',
#   'home_team': 'FC Barcelona',
#   'away_team': 'Málaga CF',
#   'home_team_goal': 6,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-03-22',
#   'country_name': 'Spain',
#   'home_team': 'RCD Mallorca',
#   'away_team': 'Atlético Madrid',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-03-21',
#   'country_name': 'Spain',
#   'home_team': 'Villarreal CF',
#   'away_team': 'Athletic Club de Bilbao',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-03-22',
#   'country_name': 'Spain',
#   'home_team': 'Real Madrid CF',
#   'away_team': 'UD Almería',
#   'home_team_goal': 3,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-04-05',
#   'country_name': 'Spain',
#   'home_team': 'Atlético Madrid',
#   'away_team': 'CA Osasuna',
#   'home_team_goal': 2,
#   'away_team_goal': 4,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-04-05',
#   'country_name': 'Spain',
#   'home_team': 'Real Sporting de Gijón',
#   'away_team': 'Racing Santander',
#   'home_team_goal': 0,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-04-04',
#   'country_name': 'Spain',
#   'home_team': 'Real Betis Balompié',
#   'away_team': 'CD Numancia',
#   'home_team_goal': 3,
#   'away_team_goal': 3,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-04-05',
#   'country_name': 'Spain',
#   'home_team': 'RCD Espanyol',
#   'away_team': 'RC Deportivo de La Coruña',
#   'home_team_goal': 3,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-04-05',
#   'country_name': 'Spain',
#   'home_team': 'Valencia CF',
#   'away_team': 'Getafe CF',
#   'home_team_goal': 4,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-04-04',
#   'country_name': 'Spain',
#   'home_team': 'UD Almería',
#   'away_team': 'Villarreal CF',
#   'home_team_goal': 3,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-04-04',
#   'country_name': 'Spain',
#   'home_team': 'Málaga CF',
#   'away_team': 'Real Madrid CF',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-04-04',
#   'country_name': 'Spain',
#   'home_team': 'Real Valladolid',
#   'away_team': 'FC Barcelona',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-04-04',
#   'country_name': 'Spain',
#   'home_team': 'Athletic Club de Bilbao',
#   'away_team': 'RCD Mallorca',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-04-04',
#   'country_name': 'Spain',
#   'home_team': 'RC Recreativo',
#   'away_team': 'Sevilla FC',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-09-21',
#   'country_name': 'Spain',
#   'home_team': 'Real Sporting de Gijón',
#   'away_team': 'FC Barcelona',
#   'home_team_goal': 1,
#   'away_team_goal': 6,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-09-21',
#   'country_name': 'Spain',
#   'home_team': 'CD Numancia',
#   'away_team': 'Villarreal CF',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-09-21',
#   'country_name': 'Spain',
#   'home_team': 'RC Deportivo de La Coruña',
#   'away_team': 'RCD Mallorca',
#   'home_team_goal': 0,
#   'away_team_goal': 0,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-09-21',
#   'country_name': 'Spain',
#   'home_team': 'Valencia CF',
#   'away_team': 'CA Osasuna',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-09-21',
#   'country_name': 'Spain',
#   'home_team': 'Real Betis Balompié',
#   'away_team': 'Sevilla FC',
#   'home_team_goal': 0,
#   'away_team_goal': 0,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-09-20',
#   'country_name': 'Spain',
#   'home_team': 'RCD Espanyol',
#   'away_team': 'Getafe CF',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2008-09-21',
#   'country_name': 'Spain',
#   'home_team': 'Racing Santander',
#   'away_team': 'Real Madrid CF',
#   'home_team_goal': 0,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2008-09-21',
#   'country_name': 'Spain',
#   'home_team': 'UD Almería',
#   'away_team': 'Málaga CF',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-09-21',
#   'country_name': 'Spain',
#   'home_team': 'Athletic Club de Bilbao',
#   'away_team': 'Real Valladolid',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2008-09-20',
#   'country_name': 'Spain',
#   'home_team': 'Atlético Madrid',
#   'away_team': 'RC Recreativo',
#   'home_team_goal': 4,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2008/2009',
#   'date': '2009-04-12',
#   'country_name': 'Spain',
#   'home_team': 'CD Numancia',
#   'away_team': 'RCD Espanyol',
#   'home_team_goal': 0,
#   'away_team_goal': 0,
#   'result': 0},
#  {'season': '2008/2009',
#   'date': '2009-04-12',
#   'country_name': 'Spain',
#   'home_team': 'Racing Santander',
#   'away_team': 'Real Betis Balompié',
#   'home_team_goal': 2,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-04-12',
#   'country_name': 'Spain',
#   'home_team': 'Real Sporting de Gijón',
#   'away_team': 'Valencia CF',
#   'home_team_goal': 2,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-04-12',
#   'country_name': 'Spain',
#   'home_team': 'RC Deportivo de La Coruña',
#   'away_team': 'Atlético Madrid',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2008/2009',
#   'date': '2009-04-12',
#   'country_name': 'Spain',
#   'home_team': 'CA Osasuna',
#   'away_team': 'Athletic Club de Bilbao',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
# ...
#   'home_team_goal': 0,
#   'away_team_goal': 0,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2011-02-19',
#   'country_name': 'Spain',
#   'home_team': 'Real Zaragoza',
#   'away_team': 'Atlético Madrid',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-02-20',
#   'country_name': 'Spain',
#   'home_team': 'Sevilla FC',
#   'away_team': 'Hércules Club de Fútbol',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-02-20',
#   'country_name': 'Spain',
#   'home_team': 'Getafe CF',
#   'away_team': 'Racing Santander',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-02-20',
#   'country_name': 'Spain',
#   'home_team': 'Villarreal CF',
#   'away_team': 'Málaga CF',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2011-02-20',
#   'country_name': 'Spain',
#   'home_team': 'UD Almería',
#   'away_team': 'RC Deportivo de La Coruña',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2011-02-19',
#   'country_name': 'Spain',
#   'home_team': 'Real Madrid CF',
#   'away_team': 'Levante UD',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-02-20',
#   'country_name': 'Spain',
#   'home_team': 'CA Osasuna',
#   'away_team': 'RCD Espanyol',
#   'home_team_goal': 4,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-02-21',
#   'country_name': 'Spain',
#   'home_team': 'Real Sociedad',
#   'away_team': 'RCD Mallorca',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-02-26',
#   'country_name': 'Spain',
#   'home_team': 'RCD Mallorca',
#   'away_team': 'FC Barcelona',
#   'home_team_goal': 0,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-02-27',
#   'country_name': 'Spain',
#   'home_team': 'Athletic Club de Bilbao',
#   'away_team': 'Valencia CF',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-02-26',
#   'country_name': 'Spain',
#   'home_team': 'Real Sporting de Gijón',
#   'away_team': 'Real Zaragoza',
#   'home_team_goal': 0,
#   'away_team_goal': 0,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2011-02-26',
#   'country_name': 'Spain',
#   'home_team': 'Atlético Madrid',
#   'away_team': 'Sevilla FC',
#   'home_team_goal': 2,
#   'away_team_goal': 2,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2011-02-27',
#   'country_name': 'Spain',
#   'home_team': 'Hércules Club de Fútbol',
#   'away_team': 'Getafe CF',
#   'home_team_goal': 0,
#   'away_team_goal': 0,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2011-02-27',
#   'country_name': 'Spain',
#   'home_team': 'Racing Santander',
#   'away_team': 'Villarreal CF',
#   'home_team_goal': 2,
#   'away_team_goal': 2,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2011-02-28',
#   'country_name': 'Spain',
#   'home_team': 'Málaga CF',
#   'away_team': 'UD Almería',
#   'home_team_goal': 3,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-02-26',
#   'country_name': 'Spain',
#   'home_team': 'RC Deportivo de La Coruña',
#   'away_team': 'Real Madrid CF',
#   'home_team_goal': 0,
#   'away_team_goal': 0,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2011-02-27',
#   'country_name': 'Spain',
#   'home_team': 'Levante UD',
#   'away_team': 'CA Osasuna',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-02-26',
#   'country_name': 'Spain',
#   'home_team': 'RCD Espanyol',
#   'away_team': 'Real Sociedad',
#   'home_team_goal': 4,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-02',
#   'country_name': 'Spain',
#   'home_team': 'Valencia CF',
#   'away_team': 'FC Barcelona',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-03-02',
#   'country_name': 'Spain',
#   'home_team': 'Real Zaragoza',
#   'away_team': 'Athletic Club de Bilbao',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-01',
#   'country_name': 'Spain',
#   'home_team': 'Sevilla FC',
#   'away_team': 'Real Sporting de Gijón',
#   'home_team_goal': 3,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-02',
#   'country_name': 'Spain',
#   'home_team': 'Getafe CF',
#   'away_team': 'Atlético Madrid',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2011-03-02',
#   'country_name': 'Spain',
#   'home_team': 'Villarreal CF',
#   'away_team': 'Hércules Club de Fútbol',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-03',
#   'country_name': 'Spain',
#   'home_team': 'UD Almería',
#   'away_team': 'Racing Santander',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2011-03-03',
#   'country_name': 'Spain',
#   'home_team': 'Real Madrid CF',
#   'away_team': 'Málaga CF',
#   'home_team_goal': 7,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-02',
#   'country_name': 'Spain',
#   'home_team': 'CA Osasuna',
#   'away_team': 'RC Deportivo de La Coruña',
#   'home_team_goal': 0,
#   'away_team_goal': 0,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2011-03-02',
#   'country_name': 'Spain',
#   'home_team': 'Real Sociedad',
#   'away_team': 'Levante UD',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2011-03-01',
#   'country_name': 'Spain',
#   'home_team': 'RCD Espanyol',
#   'away_team': 'RCD Mallorca',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-03-05',
#   'country_name': 'Spain',
#   'home_team': 'RCD Mallorca',
#   'away_team': 'Valencia CF',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-03-05',
#   'country_name': 'Spain',
#   'home_team': 'FC Barcelona',
#   'away_team': 'Real Zaragoza',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-06',
#   'country_name': 'Spain',
#   'home_team': 'Athletic Club de Bilbao',
#   'away_team': 'Sevilla FC',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-06',
#   'country_name': 'Spain',
#   'home_team': 'Real Sporting de Gijón',
#   'away_team': 'Getafe CF',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-05',
#   'country_name': 'Spain',
#   'home_team': 'Atlético Madrid',
#   'away_team': 'Villarreal CF',
#   'home_team_goal': 3,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-06',
#   'country_name': 'Spain',
#   'home_team': 'Hércules Club de Fútbol',
#   'away_team': 'UD Almería',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-03-06',
#   'country_name': 'Spain',
#   'home_team': 'Racing Santander',
#   'away_team': 'Real Madrid CF',
#   'home_team_goal': 1,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-03-06',
#   'country_name': 'Spain',
#   'home_team': 'Málaga CF',
#   'away_team': 'CA Osasuna',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-03-07',
#   'country_name': 'Spain',
#   'home_team': 'RC Deportivo de La Coruña',
#   'away_team': 'Real Sociedad',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-06',
#   'country_name': 'Spain',
#   'home_team': 'Levante UD',
#   'away_team': 'RCD Espanyol',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-13',
#   'country_name': 'Spain',
#   'home_team': 'Villarreal CF',
#   'away_team': 'Real Sporting de Gijón',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2011-03-12',
#   'country_name': 'Spain',
#   'home_team': 'Real Zaragoza',
#   'away_team': 'Valencia CF',
#   'home_team_goal': 4,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-13',
#   'country_name': 'Spain',
#   'home_team': 'Sevilla FC',
#   'away_team': 'FC Barcelona',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2011-03-14',
#   'country_name': 'Spain',
#   'home_team': 'Getafe CF',
#   'away_team': 'Athletic Club de Bilbao',
#   'home_team_goal': 2,
#   'away_team_goal': 2,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2011-03-12',
#   'country_name': 'Spain',
#   'home_team': 'UD Almería',
#   'away_team': 'Atlético Madrid',
#   'home_team_goal': 2,
#   'away_team_goal': 2,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2011-03-12',
#   'country_name': 'Spain',
#   'home_team': 'Real Madrid CF',
#   'away_team': 'Hércules Club de Fútbol',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-13',
#   'country_name': 'Spain',
#   'home_team': 'CA Osasuna',
#   'away_team': 'Racing Santander',
#   'home_team_goal': 3,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-13',
#   'country_name': 'Spain',
#   'home_team': 'Real Sociedad',
#   'away_team': 'Málaga CF',
#   'home_team_goal': 0,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-03-13',
#   'country_name': 'Spain',
#   'home_team': 'Levante UD',
#   'away_team': 'RCD Mallorca',
#   'home_team_goal': 1,
#   'away_team_goal': 1,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2011-03-13',
#   'country_name': 'Spain',
#   'home_team': 'RCD Espanyol',
#   'away_team': 'RC Deportivo de La Coruña',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-19',
#   'country_name': 'Spain',
#   'home_team': 'RCD Mallorca',
#   'away_team': 'Real Zaragoza',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-20',
#   'country_name': 'Spain',
#   'home_team': 'Valencia CF',
#   'away_team': 'Sevilla FC',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-03-19',
#   'country_name': 'Spain',
#   'home_team': 'FC Barcelona',
#   'away_team': 'Getafe CF',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-20',
#   'country_name': 'Spain',
#   'home_team': 'Athletic Club de Bilbao',
#   'away_team': 'Villarreal CF',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-03-20',
#   'country_name': 'Spain',
#   'home_team': 'Real Sporting de Gijón',
#   'away_team': 'UD Almería',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-19',
#   'country_name': 'Spain',
#   'home_team': 'Atlético Madrid',
#   'away_team': 'Real Madrid CF',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-03-20',
#   'country_name': 'Spain',
#   'home_team': 'Hércules Club de Fútbol',
#   'away_team': 'CA Osasuna',
#   'home_team_goal': 0,
#   'away_team_goal': 4,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-03-20',
#   'country_name': 'Spain',
#   'home_team': 'Racing Santander',
#   'away_team': 'Real Sociedad',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-20',
#   'country_name': 'Spain',
#   'home_team': 'Málaga CF',
#   'away_team': 'RCD Espanyol',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-03-20',
#   'country_name': 'Spain',
#   'home_team': 'RC Deportivo de La Coruña',
#   'away_team': 'Levante UD',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2010-09-18',
#   'country_name': 'Spain',
#   'home_team': 'Real Sporting de Gijón',
#   'away_team': 'Athletic Club de Bilbao',
#   'home_team_goal': 2,
#   'away_team_goal': 2,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2010-09-19',
#   'country_name': 'Spain',
#   'home_team': 'Atlético Madrid',
#   'away_team': 'FC Barcelona',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2010-09-19',
#   'country_name': 'Spain',
#   'home_team': 'Hércules Club de Fútbol',
#   'away_team': 'Valencia CF',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2010-09-19',
#   'country_name': 'Spain',
#   'home_team': 'Racing Santander',
#   'away_team': 'Real Zaragoza',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2010-09-19',
#   'country_name': 'Spain',
#   'home_team': 'Málaga CF',
#   'away_team': 'Sevilla FC',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2010-09-20',
#   'country_name': 'Spain',
#   'home_team': 'RC Deportivo de La Coruña',
#   'away_team': 'Getafe CF',
#   'home_team_goal': 2,
#   'away_team_goal': 2,
#   'result': 0},
#  {'season': '2010/2011',
#   'date': '2010-09-19',
#   'country_name': 'Spain',
#   'home_team': 'Levante UD',
#   'away_team': 'Villarreal CF',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2010-09-18',
#   'country_name': 'Spain',
#   'home_team': 'RCD Espanyol',
#   'away_team': 'UD Almería',
#   'home_team_goal': 1,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2010-09-18',
#   'country_name': 'Spain',
#   'home_team': 'Real Sociedad',
#   'away_team': 'Real Madrid CF',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2010-09-18',
#   'country_name': 'Spain',
#   'home_team': 'RCD Mallorca',
#   'away_team': 'CA Osasuna',
#   'home_team_goal': 2,
#   'away_team_goal': 0,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-04-03',
#   'country_name': 'Spain',
#   'home_team': 'Sevilla FC',
#   'away_team': 'Real Zaragoza',
#   'home_team_goal': 3,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-04-02',
#   'country_name': 'Spain',
#   'home_team': 'Getafe CF',
#   'away_team': 'Valencia CF',
#   'home_team_goal': 2,
#   'away_team_goal': 4,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-04-02',
#   'country_name': 'Spain',
#   'home_team': 'Villarreal CF',
#   'away_team': 'FC Barcelona',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-04-04',
#   'country_name': 'Spain',
#   'home_team': 'UD Almería',
#   'away_team': 'Athletic Club de Bilbao',
#   'home_team_goal': 1,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-04-02',
#   'country_name': 'Spain',
#   'home_team': 'Real Madrid CF',
#   'away_team': 'Real Sporting de Gijón',
#   'home_team_goal': 0,
#   'away_team_goal': 1,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-04-03',
#   'country_name': 'Spain',
#   'home_team': 'CA Osasuna',
#   'away_team': 'Atlético Madrid',
#   'home_team_goal': 2,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-04-03',
#   'country_name': 'Spain',
#   'home_team': 'Real Sociedad',
#   'away_team': 'Hércules Club de Fútbol',
#   'home_team_goal': 1,
#   'away_team_goal': 3,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-04-03',
#   'country_name': 'Spain',
#   'home_team': 'RCD Espanyol',
#   'away_team': 'Racing Santander',
#   'home_team_goal': 1,
#   'away_team_goal': 2,
#   'result': 2},
#  {'season': '2010/2011',
#   'date': '2011-04-03',
#   'country_name': 'Spain',
#   'home_team': 'Levante UD',
#   'away_team': 'Málaga CF',
#   'home_team_goal': 3,
#   'away_team_goal': 1,
#   'result': 1},
#  {'season': '2010/2011',
#   'date': '2011-04-03',
#   'country_name': 'Spain',
#   'home_team': 'RC Deportivo de La Coruña',
#   'away_team': 'RCD Mallorca',
#   'home_team_goal': 2,
#   'away_team_goal': 1,
#   'result': 1},
#  ...]
